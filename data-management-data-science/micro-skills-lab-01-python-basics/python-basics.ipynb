# %% [markdown]
# # Recitation 01 - Python Basics Mini‑Lesson & Assignment
#
# **Goal:** Practice core Python: variables & types, expressions, control flow, functions, and working with lists/dicts/sets/tuples.
#
# **Instructions:** Work top‑to‑bottom. Run example cells first, then complete each **Exercise** cell.

# %% [markdown]
# ## 1) Python Basics: Variables, Types, Expressions

# %%
# Examples — run and observe
x = 7                   # int
y = 2.5                 # float
name = "Ada"            # str
is_student = True       # bool

total = x + y
greeting = f"Hello, {name}!"
power = x ** 2
mod = x % 3

print(type(x), type(y), type(name), type(is_student))
print("total:", total, "| power:", power, "| mod:", mod)
print(greeting)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
# total: 9.5 | power: 49 | mod: 1
# Hello, Ada!

# %% [markdown]
# **Exercise 1:**
# Create variables `a` (int), `b` (float), and `msg` (string). Compute and print:
# 1. `a + b`
# 2. `a // 2` (integer division)
# 3. `len(msg)`

# %%
# Your work for Exercise 1
a = 4
b=3.8
msg = "cry"

print(a + b)
print(a // 2)
print(len(msg))
# Out:
# 7.8
# 2
# 3

# %% [markdown]
# ## 2) Strings: Methods & Slicing

# %%
# Examples — run and observe
text = "  Data Science with Python  "
print(text.strip())
print(text.lower())
print(text.upper())
print(text.replace("Python", "🐍"))
print(text[2:6])  # slicing
# Out:
# Data Science with Python
#   data science with python
#   DATA SCIENCE WITH PYTHON
#   Data Science with 🐍
# Data

# %% [markdown]
# **Exercise 2:**
# Given `s = "hello-world-python"`, print:
# - The number of characters,
# - The first 5 characters,
# - A version where `-` is replaced with a space,
# - A title‑cased version (each word capitalized).

# %%
# Your work for Exercise 2
s = "hello-world-python"

print(len(s))
print(s[:5])
print(s.replace("-", " "))
print(s.upper())
# Out:
# 18
# hello
# hello world python
# HELLO-WORLD-PYTHON

# %% [markdown]
# ## 3) Collections: Lists, Tuples, Sets, Dicts

# %%
# Examples — run and observe
nums = [3, 1, 4, 1, 5]
nums.append(9)
nums.sort()
print("list:", nums)

# Tuples (ordered, immutable)
pt = (10, 20)
print("tuple:", pt)

# Sets (unordered, unique elements)
colors = {"red", "blue", "red", "green"}
colors.add("yellow")
print("set:", colors)

# Dicts (key -> value)
student = {"name": "Ada", "id": 101, "skills": ["python", "pandas"]}
student["grad_year"] = 2026
print("dict:", student)
# Out:
# list: [1, 1, 3, 4, 5, 9]
# tuple: (10, 20)
# set: {'green', 'yellow', 'blue', 'red'}
# dict: {'name': 'Ada', 'id': 101, 'skills': ['python', 'pandas'], 'grad_year': 2026}

# %% [markdown]
# **Exercise 3:**
# 1. Start with `scores = [88, 92, 75, 92, 100]`.
#    - Add a new score `85`, then sort ascending.
#    - Remove duplicates while preserving order (hint: use a loop or dict.fromkeys).
# 2. Create a dict `person` with keys: `name`, `age`, `hobbies` (list of 2+ strings).
#    - Append a new hobby, then print a sentence using f‑string with name and hobby count.

# %%
# Your work for Exercise 3
scores = [88, 92, 75, 92, 100]
scores.append(85)
scores.sort()
print(scores)

unique_scores = list(dict.fromkeys(scores))
print(unique_scores)

person = {
    "name": "Ryan",
    "age": 20,
    "hobbies": ["coding", "reading", "traveling"]
}

person["hobbies"].append("lifting")
print(f"{person['name']} has {len(person['hobbies'])} hobbies")
# Out:
# [75, 85, 88, 92, 92, 100]
# [75, 85, 88, 92, 100]
# Ryan has 4 hobbies

# %% [markdown]
# ## 4) Control Flow: if/elif/else, loops, comprehensions

# %%
# Examples — run and observe
n = 17
if n % 2 == 0:
    kind = "even"
elif n % 3 == 0:
    kind = "divisible by 3"
else:
    kind = "odd and not divisible by 3"
print(kind)

# loops
items = ["book", "laptop", "pen"]
for i, item in enumerate(items, start=1):
    print(i, item)

# list comprehension
squares = [k*k for k in range(1, 8)]
print("squares:", squares)
# Out:
# odd and not divisible by 3
# 1 book
# 2 laptop
# 3 pen
# squares: [1, 4, 9, 16, 25, 36, 49]

# %% [markdown]
# **Exercise 4:**
# Write a loop that prints numbers **1–20**, but:
# - Print `"Fizz"` for multiples of 3,
# - `"Buzz"` for multiples of 5,
# - `"FizzBuzz"` for multiples of 15,
# - Otherwise print the number.
# (Yes, the classic 💥)

# %%
# Your work for Exercise 4
for i in range(1,21):
    if i % 15 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
